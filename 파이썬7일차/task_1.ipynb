# %% [markdown]
# 안녕하세요. 수강생 여러분~! Chapter33 ~ 41 수업은 잘 들으셨나요?
#
# Chapter33 ~ 41의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
#
# <br>
#
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>

# %% [markdown]
# ---

# %% [markdown]
# [문제 1]
#
# 사용자로부터 두 개의 숫자를 입력받아 나눗셈을 수행하는 프로그램을 작성하세요.
#
# [예외처리]
# - 입력 값이 숫자가 아닐 때 발생할 수 있는 ValueError
# - 나누는 수가 0일 때 발생할 수 있는 ZeroDivisionError
# - 위 2가지 예외처리 후 사용자에게 이해하기 쉬운 메시지 작성 후 출력되도록 코드를 작성

# %%
try:
    x, y = map(int, input("숫자를 입력해주세요.").split(' '))
    print(f'두 수를 나눈 값 :', x / y)
except ValueError:
    print("숫자를 입력해주세요")
except ZeroDivisionError:
    print('0으로 나눌 수 없습니다.')

# %% [markdown]
# ---

# %% [markdown]
# [문제 2]
#
# 파일을 읽어서 내용을 출력하는 프로그램을 작성하세요.
#
# - 파일이 존재하지 않을 때 발생하는 FileNotFoundError를 처리
# - 파일이 존재하지 않을 경우 "파일을 찾을 수 없습니다."라는 메시지를 출력

# %%
try:
    with open('OZ', 'r') as oz:
        print(oz())
except FileNotFoundError:
    print("파일을 찾을 수 없습니다.")

# %% [markdown]
# ---

# %% [markdown]
# [문제 3]
#
# 사용자로부터 여러 개의 숫자를 입력받아 리스트에 저장한 후, 사용자가 'done'이라고 입력할 때까지 계속 입력받으세요.
#
# - 입력 중 숫자가 아닌 값이 입력되면 ValueError를 처리
# - 숫자 외 값이 입력된 경우 어떤 값이 잘못 입력되었는지 사용자에게 알려주는 문구 출력<br>
#   (예: f"잘못된 값: {변수}. 숫자를 입력해주세요.")

# %%
#for문으로 어떻게 해야할까 고민 하다가 지피티의 도움으로 코드를 만들었습니다.
#lambda의 활용 시기를 잘 생각해야 할 것 같다.

numbers = []

for line in iter(lambda: input("숫자를 입력하세요. ('done'이면 종료): "), 'done'):
    try:
        numbers.append(int(line))
    except ValueError:
        print(f"잘못된 값:{변수}. 숫자를 입력하세요.")

# %% [markdown]
# ---

# %% [markdown]
# [문제 4]
#
# 사용자 정의 예외 NegativeNumberError를 생성하고, 사용자로부터 숫자를 입력받아 음수일 경우 NegativeNumberError를 발생시키는 프로그램을 작성하세요.
#
# - 예외 처리 구문을 사용하여 음수 입력 시 "양수를 입력해주세요."라는 메시지를 출력

# %%
#정답지를 보고 여러번 생각을 해봤음

class NegativeNumberError():
    def __init__(self, message) -> None:
        self.contact_name = "NegativeNumberError"
        self.message = message
        super().__init__(message)

    def __str__(self) -> str:
        return f"{self.contact_name} : {self.message}"
    
try:
    number = int(input("양수를 입력하세요"))
    if number < 0:
        raise NegativeNumberError("음수가 입력되었습니다. 양수를 입력하세요")
except NegativeNumberError as a:
    print(a)

# %% [markdown]
# ---

# %% [markdown]
# [문제 5]
#
# datetime 모듈을 사용하여 현재 날짜와 시간을 출력하는 프로그램을 작성하세요.
#
# 또한, 사용자로부터 태어난 년도를 입력받아 현재 나이를 계산하여 출력하세요.

# %%
import datetime

print("과제를 하는 오늘 날짜와 시간")
now = datetime.datetime.now()
print(now.year,"년", now.month,"월", now.day,"일", now.hour,"시", now.minute,"분", now.second,"초")

my_year = int(input("태어난 년도를 입력하세요"))
age = now.year - my_year
print(age,"살")
# Out:
# 과제를 하는 오늘 날짜와 시간
# 2025 년 11 월 27 일 18 시 3 분 1 초
# 29 살

# %% [markdown]
# ---

# %% [markdown]
# [문제 6]
#
# requests 모듈을 사용하여, 웹 페이지의 HTML을 가져오는 간단한 웹 스크레이퍼를 작성하세요.
#
# 'https://kream.co.kr/'에서<br>
# 데이터를 가져와서 상태 코드와 HTML의 첫 100자를 출력하세요.<br>
# (실습 전 requests 모듈을 설치해야 함)

# %%
#pip requets 를 사용하여 requests 설치 완료
#정답을 보고 이해완료 
import requests

response = requests.get('https://exple.com')
print("상태 코드:", response.status_code)
print("HTML 내용(첫 100자):", response.text[:100])  #<- [:100]을 사용 하여 앞에 첫 100자를 불러옴

# %% [markdown]
# ---

# %% [markdown]
# [문제 7]
#
# 함수 실행 시간을 측정하는 데코레이터 timer_decorator를 작성하세요.
#
# 임의의 함수가 실행되는 시간을 측정하여 "함수 실행 시간: x.xx초" 형태로 출력하세요.

# %%
#import time과 def timer_decorator(): 이후 정답지를 확인함으로서 이해 가능했지만 여러번 반복을 해봐야 좀 더 깊이 있게 이해 가능할 듯

import time

def timer_decorator(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = func(*args, **kwargs)
        end_time = time.time()
        elapsed = end_time - start_time
        print(f"함수 실행 시간: {elapsed:.2f}초")
        return result
    return wrapper

@timer_decorator
def example_function():
    sum = 0
    for i in range(1000000):
        sum += 1
    return sum

example_function()

# %% [markdown]
# ---

# %% [markdown]
# [문제 8]
#
# 여러분이 자주 사용하는 수학적 연산<br>
# (예: 삼각형 넓이, 원의 넓이, 직육면체의 넓이)을 수행하는 함수들을 포함하는 mymath.py라는 이름의 모듈을 만드세요.
#
# 이 모듈을 사용하여 작성된 함수들을 실제로 임포트하고 사용하는 간단한 프로그램을 작성하세요.

# %%
def Triangle_area(bowels, high):
    return 0.5 * bowels * high

def Circle_area(radius):
    return math.pi * radius ** 2

def Square_area(length, width):
    return length * width

# %%
from mymath import *

numbers = []

Triangle_area(4, 12)
print("삼각형의 넓이:", Triangle_area(bowels, high))

Circle_area(3)
print("원의 넓이:", Circle_area(radius))

Square_area(4, 9)
print("직사각형의 넓이:", Square_area(length, width))

# %% [markdown]
# ---

# %% [markdown]
# [문제 9]
#
# animals라는 패키지를 만들고, 이 패키지 내에 mammals, birds라는 두 개의 서브 모듈을 생성하세요.
#
# - 각 모듈에는 최소한 한 개 이상의 동물에 관한 클래스를 정의하세요<br>
#   (예: mammals에는 Dog, birds에는 Eagle)
# - 이 패키지와 모듈을 사용하여 동물들의 정보를 출력하는 프로그램을 작성
#
# 폴더 및 파일 구조
# ```
# animals/(폴더)
# ├── __init__.py
# ├── mammals.py
# └── birds.py
# ```

# %%
#mammals.py

class Dog():
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def zinie(self):
        return f"{self.name} Woof!"

# %%
#birds.py
class Eagle():
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def eagle(self):
        return f"{self.name} pew!!"

# %%
#실행파일
from animals.mammals import Dog
from animals.birds import Eagle

dog = Dog(zinie)
eagle = Eagle(eagle)

# %% [markdown]
# ---
